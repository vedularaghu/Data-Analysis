# %%
import os
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
from pandas import ExcelWriter
import xlrd
from tkinter import *

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }
#For the year 2014-2015
df = pd.read_excel('OT-2014-15.xls')
df = df[['AU', 'EMPNAME', 'DESG', 'SUM(AMT)']]
df = (df[df['DESG']==("AC.COACH ATTD.")])
print(df)
sum_15 = df["SUM(AMT)"].sum()
pass_15 = 4294480
cost_pass15 = round(sum_15/pass_15, 2)
attd_no15 = df.count()['AU']
avg_OT15 = round(sum_15/attd_no15, 2)

# %%
#For the year 2014-2015
df = pd.read_excel('OT-2014-15.xls')
df = df[['AU', 'EMPNAME', 'DESG', 'SUM(AMT)']]
df = (df[df['DESG']==("AC.COACH ATTD.")])
print(df)
sum_15 = df["SUM(AMT)"].sum()
pass_15 = 4294480
cost_pass15 = round(sum_15/pass_15, 2)
attd_no15 = df.count()['AU']
avg_OT15 = round(sum_15/attd_no15, 2)
# Out:
#                 AU                    EMPNAME            DESG  SUM(AMT)
# 278    KHURDA ROAD         SANJAY KUMAR HAZRA  AC.COACH ATTD.    184558
# 320    KHURDA ROAD         KISHORE KU MOHANTY  AC.COACH ATTD.    173111
# 840    KHURDA ROAD            P.TRINATH PANDA  AC.COACH ATTD.    112502
# 1290   KHURDA ROAD           PRATAP CH.MANTRI  AC.COACH ATTD.     94956
# 1299   KHURDA ROAD           ALOK CHANDRA DAS  AC.COACH ATTD.     94763
# 1409   KHURDA ROAD             P.HARI KRISHNA  AC.COACH ATTD.     91104
# 1658   KHURDA ROAD              P.SANYASI RAO  AC.COACH ATTD.     84096
# 1755   KHURDA ROAD            RAMRATAN BEHERA  AC.COACH ATTD.     82065
# 1782   KHURDA ROAD             M.KAMESWAR RAO  AC.COACH ATTD.     81346
# 1807   KHURDA ROAD          RAMACHANDRA SINGH  AC.COACH ATTD.     80992
# 1870   KHURDA ROAD           NABAKISHORE BHOI  AC.COACH ATTD.     79676
# 1874   KHURDA ROAD             S.NAGESWAR RAO  AC.COACH ATTD.     79611
# 1971   KHURDA ROAD              P.SANYASI RAO  AC.COACH ATTD.     77662
# 2009   KHURDA ROAD              G.NARAYAN RAO  AC.COACH ATTD.     76850
# 2200   KHURDA ROAD              SUKUMAR.SINGH  AC.COACH ATTD.     73438
# 2266   KHURDA ROAD              G.NARAYAN RAO  AC.COACH ATTD.     71949
# 2309   KHURDA ROAD             P.HARI KRISHNA  AC.COACH ATTD.     71262
# 2382   KHURDA ROAD             S.NAGESWAR RAO  AC.COACH ATTD.     70258
# 2418   KHURDA ROAD          ARABIND KUMAR DAS  AC.COACH ATTD.     69605
# 2713   KHURDA ROAD            P.TRINATH PANDA  AC.COACH ATTD.     65434
# 2714   KHURDA ROAD           PRATAP CH.MANTRI  AC.COACH ATTD.     65432
# 3006       WALTAIR         A.VENKATESWARA RAO  AC.COACH ATTD.     61729
# 3019   KHURDA ROAD            SAROJ KU.PRUSTY  AC.COACH ATTD.     61553
# 3154   KHURDA ROAD              R.VENKATA RAO  AC.COACH ATTD.     60092
# 3206   KHURDA ROAD             M.VENKATA GIRI  AC.COACH ATTD.     59615
# 3237   KHURDA ROAD                K.F.HUSSAIN  AC.COACH ATTD.     59302
# 3264   KHURDA ROAD            PALINI TATA RAO  AC.COACH ATTD.     59042
# 3590       WALTAIR          S. JAGANNADHA RAO  AC.COACH ATTD.     55910
# 3665   KHURDA ROAD              BIDESHI SINGH  AC.COACH ATTD.     55350
# 3711   KHURDA ROAD         NIHAR RANJAN DALAI  AC.COACH ATTD.     54977
# ...            ...                        ...             ...       ...
# 23063      WALTAIR                     VIKRAM  AC.COACH ATTD.      4863
# 23067  KHURDA ROAD              R.VENKATA RAO  AC.COACH ATTD.      4859
# 23282  KHURDA ROAD              DEBARAJ NAHAK  AC.COACH ATTD.      4672
# 23455      WALTAIR                   V.RAMESH  AC.COACH ATTD.      4529
# 23492      WALTAIR          S. JAGANNADHA RAO  AC.COACH ATTD.      4490
# 23495  KHURDA ROAD               K.CH.HEMBRAM  AC.COACH ATTD.      4485
# 23735      WALTAIR                    D.GOWRI  AC.COACH ATTD.      4262
# 23830      WALTAIR                     T.RAJU  AC.COACH ATTD.      4175
# 24008      WALTAIR  PRASANTH JAYA RAJU TRUMAN  AC.COACH ATTD.      4006
# 24224  KHURDA ROAD        PURNA CHANDRA SINGH  AC.COACH ATTD.      3823
# 24320      WALTAIR           D.G.NAVEEN KUMAR  AC.COACH ATTD.      3764
# 24323  KHURDA ROAD             BIREN KU.NAYAK  AC.COACH ATTD.      3761
# 24324      WALTAIR             M.RAMESH NAIDU  AC.COACH ATTD.      3760
# 24519      WALTAIR                  P. SURESH  AC.COACH ATTD.      3582
# 24693      WALTAIR            CH.RAMANA MURTY  AC.COACH ATTD.      3433
# 25230      WALTAIR          A.V. SANYASI RAJU  AC.COACH ATTD.      3044
# 25460      WALTAIR             M.RAMESH NAIDU  AC.COACH ATTD.      2865
# 25737  KHURDA ROAD         SAROJO KUMAR SETHY  AC.COACH ATTD.      2676
# 25766  KHURDA ROAD             KAMADEV BEHERA  AC.COACH ATTD.      2656
# 25829  KHURDA ROAD                    N.ANAND  AC.COACH ATTD.      2618
# 25977      WALTAIR                   V.RAMESH  AC.COACH ATTD.      2507
# 26418      WALTAIR                   S.PRASAD  AC.COACH ATTD.      2213
# 26678  KHURDA ROAD          RABINARAYAN SINGH  AC.COACH ATTD.      2056
# 26786      WALTAIR                    D.GOWRI  AC.COACH ATTD.      1983
# 26869  KHURDA ROAD             BIREN KU.NAYAK  AC.COACH ATTD.      1926
# 27669      WALTAIR             M.RAMESH NAIDU  AC.COACH ATTD.      1433
# 28010  KHURDA ROAD           UMAKANTA MOHANTY  AC.COACH ATTD.      1240
# 29316      WALTAIR          D. SREENIVASA RAO  AC.COACH ATTD.       540
# 29519      WALTAIR            S.SRINIVASA RAO  AC.COACH ATTD.       430
# 29995      WALTAIR                   S.PRASAD  AC.COACH ATTD.       201
#
# [475 rows x 4 columns]

# %%
#For the year 2015-2016
df = pd.read_excel('OT-2015-16.xls')
df = df[['AU', 'EMPNAME', 'DESG', 'SUM(AMT)']]
df = (df[df['DESG']==("AC.COACH ATTD.")])
print(df)
sum_16 = df["SUM(AMT)"].sum()
pass_16=4739961
cost_pass16 = round(sum_16/pass_16, 2)
attd_no16 = df.count()['AU']
avg_OT16 = round(sum_16/attd_no16, 2)
# Out:
#                AU                    EMPNAME            DESG  SUM(AMT)
# 1162      WALTAIR            CH.RAMANA MURTY  AC.COACH ATTD.     15764
# 1200      WALTAIR           M.V. ANAND KUMAR  AC.COACH ATTD.     15164
# 1730      WALTAIR                     VIKRAM  AC.COACH ATTD.      8880
# 12    KHURDA ROAD           ALOK CHANDRA DAS  AC.COACH ATTD.    151665
# 30    KHURDA ROAD              G.NARAYAN RAO  AC.COACH ATTD.    132356
# 31    KHURDA ROAD         KISHORE KU MOHANTY  AC.COACH ATTD.    132211
# 72    KHURDA ROAD             P.HARI KRISHNA  AC.COACH ATTD.    100554
# 108   KHURDA ROAD         BHUBANANANDA NAYAK  AC.COACH ATTD.     80598
# 116   KHURDA ROAD         SANJAY KUMAR HAZRA  AC.COACH ATTD.     77581
# 148   KHURDA ROAD           PRATAP CH.MANTRI  AC.COACH ATTD.     69041
# 193   KHURDA ROAD           NABAKISHORE BHOI  AC.COACH ATTD.     59871
# 276   KHURDA ROAD            PITABAS BASTYA.  AC.COACH ATTD.     47165
# 280   KHURDA ROAD               V.CHANDRAYYA  AC.COACH ATTD.     46696
# 390   KHURDA ROAD              BIDESHI SINGH  AC.COACH ATTD.     36977
# 422   KHURDA ROAD           CHITTARANJAN DAS  AC.COACH ATTD.     34900
# 660   KHURDA ROAD         PURNA CHANDRA JENA  AC.COACH ATTD.     25125
# 796   KHURDA ROAD          P. SRINIVAS NAIDU  AC.COACH ATTD.     21429
# 1352  KHURDA ROAD            SANJAYA KU JENA  AC.COACH ATTD.     10799
# 1400  KHURDA ROAD            JAY KRUSHNA DAS  AC.COACH ATTD.      9910
# 244   KHURDA ROAD            P.TRINATH PANDA  AC.COACH ATTD.     58379
# 263       WALTAIR            RAMESH MADHAVAN  AC.COACH ATTD.     56488
# 312   KHURDA ROAD                   B.R.RAO.  AC.COACH ATTD.     52774
# 465       WALTAIR          S. JAGANNADHA RAO  AC.COACH ATTD.     43828
# 517   KHURDA ROAD              R.VENKATA RAO  AC.COACH ATTD.     41360
# 547   KHURDA ROAD              SUKUMAR.SINGH  AC.COACH ATTD.     39892
# 555   KHURDA ROAD              P.SANYASI RAO  AC.COACH ATTD.     39637
# 581   KHURDA ROAD                 Y.RAMA RAO  AC.COACH ATTD.     38570
# 613       WALTAIR         A.VENKATESWARA RAO  AC.COACH ATTD.     37409
# 616   KHURDA ROAD               U.ANANDA RAO  AC.COACH ATTD.     37268
# 628       WALTAIR         P.ADIMOHANA  REDDY  AC.COACH ATTD.     36629
# ...           ...                        ...             ...       ...
# 1665  KHURDA ROAD             M.MARKONDEYULU  AC.COACH ATTD.      4187
# 1685  KHURDA ROAD              P.SANYASI RAO  AC.COACH ATTD.      3978
# 1748  KHURDA ROAD        MAHENDRA KU.MALLICK  AC.COACH ATTD.      3284
# 1884  KHURDA ROAD         NIHAR RANJAN DALAI  AC.COACH ATTD.      1639
# 1967      WALTAIR          A.V. SANYASI RAJU  AC.COACH ATTD.       943
# 1983  KHURDA ROAD              CHARAN BEHERA  AC.COACH ATTD.       837
# 372       WALTAIR           M.V. ANAND KUMAR  AC.COACH ATTD.     41851
# 612       WALTAIR         A.VENKATESWARA RAO  AC.COACH ATTD.     32545
# 659       WALTAIR                     VIKRAM  AC.COACH ATTD.     30944
# 868       WALTAIR             SHANKAR MONDAL  AC.COACH ATTD.     26351
# 1146      WALTAIR            RAMESH MADHAVAN  AC.COACH ATTD.     21611
# 1196      WALTAIR          S. JAGANNADHA RAO  AC.COACH ATTD.     20902
# 1315      WALTAIR                   J.RAMESH  AC.COACH ATTD.     19303
# 1379      WALTAIR                 ANIL KUMAR  AC.COACH ATTD.     18405
# 1391      WALTAIR              G.PRASADA RAO  AC.COACH ATTD.     18197
# 1394      WALTAIR                    D.GOWRI  AC.COACH ATTD.     18136
# 1465      WALTAIR           D.G.NAVEEN KUMAR  AC.COACH ATTD.     17004
# 1509      WALTAIR                  P. SURESH  AC.COACH ATTD.     16309
# 1549      WALTAIR                     T.RAJU  AC.COACH ATTD.     15687
# 1635      WALTAIR       M.GRUHALINGESWARARAO  AC.COACH ATTD.     14460
# 2219      WALTAIR           CH.SRINIVASA RAO  AC.COACH ATTD.      8069
# 2300      WALTAIR               K.RAVI KUMAR  AC.COACH ATTD.      7476
# 2322      WALTAIR             S. VENKATA RAO  AC.COACH ATTD.      7246
# 2408      WALTAIR  PRASANTH JAYA RAJU TRUMAN  AC.COACH ATTD.      6621
# 2658      WALTAIR                P.RAMASWAMY  AC.COACH ATTD.      5000
# 2907      WALTAIR          A.V. SANYASI RAJU  AC.COACH ATTD.      3411
# 2941      WALTAIR            S.SRINIVASA RAO  AC.COACH ATTD.      3128
# 3359      WALTAIR          D. SREENIVASA RAO  AC.COACH ATTD.       640
# 3360      WALTAIR               P.RAMANA RAO  AC.COACH ATTD.       637
# 3454      WALTAIR             A.VIJAYA KUMAR  AC.COACH ATTD.       197
#
# [396 rows x 4 columns]

# %%
#For the year 2016-2017
df = pd.read_excel('OT-2016-17.xls')    
df = df[['AU', 'EMPNAME', 'DESG', 'SUM(AMT)']]
df = (df[df['DESG']==("AC.COACH ATTD.")])
print(df)
sum_17 = df["SUM(AMT)"].sum()
pass_17=5092085
cost_pass17 = round(sum_17/pass_17, 2)
attd_no17 = df.count()['AU']
avg_OT17 = round(sum_17/attd_no17, 2)
# Out:
#                AU                    EMPNAME            DESG  SUM(AMT)
# 9     KHURDA ROAD           PRATAP CH.MANTRI  AC.COACH ATTD.    114556
# 17    KHURDA ROAD              G.NARAYAN RAO  AC.COACH ATTD.     98451
# 18    KHURDA ROAD              BIDESHI SINGH  AC.COACH ATTD.     96562
# 20    KHURDA ROAD             P.HARI KRISHNA  AC.COACH ATTD.     96350
# 46    KHURDA ROAD               V.CHANDRAYYA  AC.COACH ATTD.     63701
# 63    KHURDA ROAD          P. SRINIVAS NAIDU  AC.COACH ATTD.     53722
# 102   KHURDA ROAD           CHITTARANJAN DAS  AC.COACH ATTD.     41676
# 142   KHURDA ROAD         BHUBANANANDA NAYAK  AC.COACH ATTD.     37079
# 232   KHURDA ROAD            PITABAS BASTYA.  AC.COACH ATTD.     28904
# 88        WALTAIR                 ANIL KUMAR  AC.COACH ATTD.     64584
# 182       WALTAIR         A.VENKATESWARA RAO  AC.COACH ATTD.     51756
# 187       WALTAIR                   J.RAMESH  AC.COACH ATTD.     51386
# 300       WALTAIR           D.G.NAVEEN KUMAR  AC.COACH ATTD.     42821
# 374       WALTAIR          S. JAGANNADHA RAO  AC.COACH ATTD.     39218
# 537       WALTAIR            RAMESH MADHAVAN  AC.COACH ATTD.     30997
# 600       WALTAIR           CH.SRINIVASA RAO  AC.COACH ATTD.     28025
# 625       WALTAIR           M.V. ANAND KUMAR  AC.COACH ATTD.     27048
# 645       WALTAIR              G.PRASADA RAO  AC.COACH ATTD.     26102
# 686       WALTAIR       M.GRUHALINGESWARARAO  AC.COACH ATTD.     24244
# 774       WALTAIR                    D.GOWRI  AC.COACH ATTD.     21452
# 831       WALTAIR                  P. SURESH  AC.COACH ATTD.     19864
# 996       WALTAIR                     T.RAJU  AC.COACH ATTD.     15920
# 1233      WALTAIR                P.RAMASWAMY  AC.COACH ATTD.     10955
# 1631      WALTAIR          D. SREENIVASA RAO  AC.COACH ATTD.      5189
# 1653      WALTAIR            CH.RAMANA MURTY  AC.COACH ATTD.      4904
# 1748      WALTAIR                     VIKRAM  AC.COACH ATTD.      3861
# 1797      WALTAIR            S.SRINIVASA RAO  AC.COACH ATTD.      3477
# 1964      WALTAIR  PRASANTH JAYA RAJU TRUMAN  AC.COACH ATTD.      1746
# 1974      WALTAIR             S. VENKATA RAO  AC.COACH ATTD.      1577
# 63        WALTAIR                 ANIL KUMAR  AC.COACH ATTD.     61875
# ...           ...                        ...             ...       ...
# 1195  KHURDA ROAD              PRABAKAR JENA  AC.COACH ATTD.     16980
# 1297  KHURDA ROAD             M.VENKATA GIRI  AC.COACH ATTD.     14923
# 1367  KHURDA ROAD          D.LAKSHMINARAYANA  AC.COACH ATTD.     13794
# 1471  KHURDA ROAD           S.V.GOPI KRISHNA  AC.COACH ATTD.     12080
# 1574  KHURDA ROAD                  K.GURAYYA  AC.COACH ATTD.     10109
# 1605  KHURDA ROAD             BIREN KU.NAYAK  AC.COACH ATTD.      9653
# 1607  KHURDA ROAD  SUBHRA PRATIM CHAKRABORTY  AC.COACH ATTD.      9615
# 1630  KHURDA ROAD         NIHAR RANJAN DALAI  AC.COACH ATTD.      9182
# 1800  KHURDA ROAD        PRASANT KUMAR BARIK  AC.COACH ATTD.      6158
# 1850  KHURDA ROAD        PURNA CHANDRA SINGH  AC.COACH ATTD.      5177
# 1894  KHURDA ROAD                  P.PAIKRAY  AC.COACH ATTD.      4680
# 1989  KHURDA ROAD             S.NAGESWAR RAO  AC.COACH ATTD.      3247
# 2083  KHURDA ROAD           BISWAJIT MOHANTY  AC.COACH ATTD.      1648
# 2142  KHURDA ROAD                K.F.HUSSAIN  AC.COACH ATTD.       986
# 643       WALTAIR       M.GRUHALINGESWARARAO  AC.COACH ATTD.     34188
# 711       WALTAIR         A.VENKATESWARA RAO  AC.COACH ATTD.     31579
# 733       WALTAIR                 ANIL KUMAR  AC.COACH ATTD.     31089
# 857       WALTAIR                   J.RAMESH  AC.COACH ATTD.     27184
# 1028      WALTAIR              G.PRASADA RAO  AC.COACH ATTD.     23081
# 1116      WALTAIR          D. SREENIVASA RAO  AC.COACH ATTD.     21559
# 1214      WALTAIR            RAMESH MADHAVAN  AC.COACH ATTD.     20011
# 1426      WALTAIR                     T.RAJU  AC.COACH ATTD.     16811
# 1520      WALTAIR          S. JAGANNADHA RAO  AC.COACH ATTD.     15629
# 1541      WALTAIR           CH.SRINIVASA RAO  AC.COACH ATTD.     15325
# 1665      WALTAIR                  P. SURESH  AC.COACH ATTD.     13905
# 2133      WALTAIR                    D.GOWRI  AC.COACH ATTD.      9048
# 2144      WALTAIR                     VIKRAM  AC.COACH ATTD.      8907
# 2217      WALTAIR         P.ADIMOHANA  REDDY  AC.COACH ATTD.      8154
# 2342      WALTAIR            CH.RAMANA MURTY  AC.COACH ATTD.      7018
# 3030      WALTAIR           M.V. ANAND KUMAR  AC.COACH ATTD.       632
#
# [301 rows x 4 columns]

# %%
print("\n\nAnalysis for the year 2014-15\n")
print("The total OT claimed in 2014-15 is Rs.", sum_15)
print("The total number of passengers in 2014-15 is ", pass_15)
print("The Cost per passenger in 2014-15 is Rs.", cost_pass15)
print("The number of AC Coach Attendant who claimed OT = ", attd_no15)
print("Average OT claimed by AC Coach Attendant in 2014-15 is Rs. ", avg_OT15)
# Out:
# Analysis for the year 2014-15
#
# The total OT claimed in 2014-15 is Rs. 12336118
# The total number of passengers in 2014-15 is  4294480
# The Cost per passenger in 2014-15 is Rs. 2.87
# The number of AC Coach Attendant who claimed OT =  475
# Average OT claimed by AC Coach Attendant in 2014-15 is Rs.  25970.77

# %%
print("\n\nAnalysis for the year 2015-16\n")
print("The total OT claimed in 2015-16 is Rs.", sum_16)
print("The total number of passengers in 2015-16 is ", pass_16)
print("The Cost per passenger in 2015-16 is Rs.", cost_pass16)
print("The number of AC Coach Attendant who claimed OT = ", attd_no16)
print("Average OT claimed by AC Coach Attendant in 2015-16 is Rs. ", avg_OT16)
# Out:
# Analysis for the year 2015-16
#
# The total OT claimed in 2015-16 is Rs. 10824072
# The total number of passengers in 2015-16 is  4739961
# The Cost per passenger in 2015-16 is Rs. 2.28
# The number of AC Coach Attendant who claimed OT =  396
# Average OT claimed by AC Coach Attendant in 2015-16 is Rs.  27333.52

# %%
print("\n\nAnalysis for the year 2016-17\n")
print("The total OT claimed in 2016-17 is Rs.", sum_17)
print("The total number of passengers in 2016-17 is ", pass_17)
print("The Cost per passenger in 2016-17 is Rs.", cost_pass17)
print("The number of AC Coach Attendant who claimed OT = ", attd_no17)
print("Average OT claimed by AC Coach Attendant in 2016-17 is Rs. ", avg_OT17)
# Out:
# Analysis for the year 2016-17
#
# The total OT claimed in 2016-17 is Rs. 8224458
# The total number of passengers in 2016-17 is  5092085
# The Cost per passenger in 2016-17 is Rs. 1.62
# The number of AC Coach Attendant who claimed OT =  301
# Average OT claimed by AC Coach Attendant in 2016-17 is Rs.  27323.78

# %%
objects = ('2014-15', '2015-16', '2016-17')
x_pos = np.arange(len(objects))
costpass = [cost_pass15, cost_pass16, cost_pass17]
avgOT = [avg_OT15, avg_OT16, avg_OT17]

# %%
plt.bar(x_pos, costpass, align='center', alpha=0.5)
plt.xticks(x_pos, objects)
plt.ylabel('Cost per AC passenger')
plt.title('OT of AC Coach Attendant')
plt.show()

# %%
plt.plot(x_pos, costpass, '-o')
plt.xticks(x_pos, objects)
plt.text(0.9, 2.4, 'ECoR', fontdict=font)
plt.ylabel('Cost per AC passenger')
plt.title('OT of Coach Attendant')
plt.axis([-1, 3, 1, 3])
plt.show()

# %%
plt.plot(x_pos, avgOT, '-o')
plt.xticks(x_pos, objects)
plt.text(0.9, 2.4, 'ECoR', fontdict=font)
plt.ylabel('Average OT claimed')
plt.title('Average OT claimed by AC Coach Attendant over years')
plt.axis([-1, 3, 25000, 30000])
plt.show()
